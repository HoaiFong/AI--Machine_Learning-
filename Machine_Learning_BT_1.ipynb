# %%
import pandas as pd
import numpy as np
url = 'crabs.csv'
data = pd.read_csv(url)
from matplotlib import pyplot as plt
data.hist() # hàm histogram
plt.show()

# %%
correlation = data.corr() #mối tương quan giữa các giá trị 
print(correlation)
# Out:
#               index  fontallip  rearwidth    length     width     depth
# index      1.000000   0.862876   0.840040  0.911436  0.928248  0.864459
# fontallip  0.862876   1.000000   0.906988  0.978842  0.964956  0.987627
# rearwidth  0.840040   0.906988   1.000000  0.892743  0.900402  0.889205
# length     0.911436   0.978842   0.892743  1.000000  0.995023  0.983204
# width      0.928248   0.964956   0.900402  0.995023  1.000000  0.967812
# depth      0.864459   0.987627   0.889205  0.983204  0.967812  1.000000

# %%
import seaborn as sns
sns.heatmap(correlation, annot = True)
# Out:
# <AxesSubplot:>

# %%
data.plot(kind = 'scatter',x = 'depth',y='fontallip',figsize = (9,9), color = 'black')
# Out:
# <AxesSubplot:xlabel='depth', ylabel='fontallip'>

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()
model.fit(X = pd.DataFrame(data['depth']),y= data['fontallip'])
print(model.intercept_)
print(model.coef_)
# y = coef*x + intercept
# coef : hệ số góc, intercept : giao điểm với trụ Y
model.score(X = pd.DataFrame(data['depth']),y= data['fontallip']) #độ chính xác
# Out:
# 1.4406342304011854
# [1.00797304]
# 0.9754074794865865

# %%
data.plot(kind = 'scatter', x = 'depth', y = 'fontallip', figsize = (9,9), color = 'black', xlim = (0.7))
y_pred = model.predict(X = pd.DataFrame(data['depth']))
plt.plot(data['depth'],y_pred,color='blue')

# %%
# hàm bậc 2
model = linear_model.LinearRegression()
X = pd.DataFrame([data['depth'], data['depth']**2]).T
model.fit(X, y=data['fontallip'])
print('Intercept cua mo hinh: ',model.intercept_)
print('Coeffient cua mo hinh: ',model.coef_)
z = model.score(X,y =data['fontallip'])
print('Do chinh xac cua mo hinh: ',z)
# Out:
# Intercept cua mo hinh:  1.017938871483981
# Coeffient cua mo hinh:  [ 1.07185355 -0.00227109]
# Do chinh xac cua mo hinh:  0.9754898977011875

# %%
range = np.arange(2.5,30,0.1)
data.plot(kind = 'scatter', x = 'depth', y = 'fontallip', figsize = (9,9), color = 'black', xlim = (0.7))
predictor = pd.DataFrame([range,range**2]).T
y_pred = model.predict(X = predictor)
plt.plot(range, y_pred,color = 'blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# hàm bậc 5
model = linear_model.LinearRegression()
X = pd.DataFrame([data['depth'], data['depth']**2,data['depth']**3,data['depth']**4,data['depth']**5]).T
model.fit(X, y=data['fontallip'])
print('Intercept cua mo hinh: ',model.intercept_)
print('Coeffient cua mo hinh: ',model.coef_)
z = model.score(X,y =data['depth'])
print('Do chinh xac cua mo hinh: ',z)
# Out:
# Intercept cua mo hinh:  -13.480238029127579
# Coeffient cua mo hinh:  [ 6.95566518e+00 -9.08409686e-01  6.64490240e-02 -2.33023554e-03
#   3.13960897e-05]
# Do chinh xac cua mo hinh:  0.7930644210307402

# %%
range = np.arange(2.5,25,0.1)
data.plot(kind = 'scatter', x = 'depth', y = 'fontallip', figsize = (9,9), color = 'black', xlim = (0.7))
predictor = pd.DataFrame([range,range**2,range**3,range**4,range**5]).T
y_pred = model.predict(X = predictor)
plt.plot(range, y_pred,color = 'blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
