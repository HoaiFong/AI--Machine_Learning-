# %%
import pandas as pd
import numpy as np
url = 'lung_cancer_examples.csv'
data = pd.read_csv(url)
from matplotlib import pyplot as plt
data.hist() # hàm histogram
plt.show()

# %%
correlation = data.corr() #mối tương quan giữa các giá trị 
print(correlation)
# Out:
#              Age    Smokes     AreaQ    Alkhol    Result
# Age     1.000000  0.053665 -0.268957  0.318621  0.637726
# Smokes  0.053665  1.000000 -0.353295  0.469915  0.373444
# AreaQ  -0.268957 -0.353295  1.000000 -0.714412 -0.746621
# Alkhol  0.318621  0.469915 -0.714412  1.000000  0.810439
# Result  0.637726  0.373444 -0.746621  0.810439  1.000000

# %%
import seaborn as sns
sns.heatmap(correlation, annot = True)
# Out:
# <AxesSubplot:>

# %%
data.plot(kind = 'scatter',x = 'Alkhol',y='Smokes',figsize = (9,9), color = 'black')
# Out:
# <AxesSubplot:xlabel='Alkhol', ylabel='Smokes'>

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()
model.fit(X = pd.DataFrame(data['Alkhol']),y= data['Smokes'])
print(model.intercept_)
print(model.coef_)
# y = coef*x + intercept
# coef : hệ số góc, intercept : giao điểm với trụ Y
model.score(X = pd.DataFrame(data['Alkhol']),y= data['Smokes']) #độ chính xác
# Out:
# 9.965294966996698
# [1.57616543]
# 0.22082036769568314

# %%
data.plot(kind = 'scatter', x = 'Alkhol', y = 'Smokes', figsize = (9,9), color = 'black', xlim = (0.7))
y_pred = model.predict(X = pd.DataFrame(data['Alkhol']))
plt.plot(data['Alkhol'],y_pred,color='blue')

# %%
# hàm bậc 3
model = linear_model.LinearRegression()
X = pd.DataFrame([data['Alkhol'], data['Alkhol']**2,data['Alkhol']**3]).T
model.fit(X, y=data['Smokes'])
print('Intercept cua mo hinh: ',model.intercept_)
print('Coeffient cua mo hinh: ',model.coef_)
z = model.score(X,y =data['Smokes'])
print('Do chinh xac cua mo hinh: ',z)
# Out:
# Intercept cua mo hinh:  8.835420396928336
# Coeffient cua mo hinh:  [ 4.0109987  -0.83456171  0.07063244]
# Do chinh xac cua mo hinh:  0.23325346323607032

# %%
range = np.arange(1,9,0.1)
data.plot(kind = 'scatter', x = 'Alkhol', y = 'Smokes', figsize = (9,9), color = 'black', xlim = (0.7))
predictor = pd.DataFrame([range,range**2,range**3]).T
y_pred = model.predict(X = predictor)
plt.plot(range, y_pred,color = 'blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# hàm bậc 5
model = linear_model.LinearRegression()
X = pd.DataFrame([data['Alkhol'], data['Alkhol']**2,data['Alkhol']**3,data['Alkhol']**4,data['Alkhol']**5]).T
model.fit(X, y=data['Smokes'])
print('Intercept cua mo hinh: ',model.intercept_)
print('Coeffient cua mo hinh: ',model.coef_)
z = model.score(X,y =data['Smokes'])
print('Do chinh xac cua mo hinh: ',z)
# Out:
# Intercept cua mo hinh:  10.172351000365433
# Coeffient cua mo hinh:  [-3.09588492e+00  3.60314030e+00 -6.96257507e-01  1.55122844e-02
#   3.10945896e-03]
# Do chinh xac cua mo hinh:  0.2800190548444893

# %%
range = np.arange(1,9,0.1)
data.plot(kind = 'scatter', x = 'Alkhol', y = 'Smokes', figsize = (9,9), color = 'black', xlim = (0.7))
predictor = pd.DataFrame([range,range**2,range**3,range**4,range**5]).T
y_pred = model.predict(X = predictor)
plt.plot(range, y_pred,color = 'blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
