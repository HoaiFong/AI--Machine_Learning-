# %%
import pandas as pd
import numpy as np
url = 'iris.csv'
data = pd.read_csv(url)
from matplotlib import pyplot as plt
data.hist() # hàm histogram
plt.show()

# %%
correlation = data.corr() #mối tương quan giữa các giá trị 
print(correlation)
# Out:
#               sepal.length  sepal.width  petal.length  petal.width
# sepal.length      1.000000    -0.117570      0.871754     0.817941
# sepal.width      -0.117570     1.000000     -0.428440    -0.366126
# petal.length      0.871754    -0.428440      1.000000     0.962865
# petal.width       0.817941    -0.366126      0.962865     1.000000

# %%
import seaborn as sns
sns.heatmap(correlation, annot = True)
# Out:
# <AxesSubplot:>

# %%
data.plot(kind = 'scatter',x = 'petal.width',y='petal.length',figsize = (9,9), color = 'black')
# Out:
# <AxesSubplot:xlabel='petal.width', ylabel='petal.length'>

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()
model.fit(X = pd.DataFrame(data['petal.width']),y= data['petal.length'])
print(model.intercept_)
print(model.coef_)
# y = coef*x + intercept
# coef : hệ số góc, intercept : giao điểm với trụ Y
model.score(X = pd.DataFrame(data['petal.width']),y= data['petal.length']) #độ chính xác
# Out:
# 1.0835580328505112
# [2.2299405]
# 0.9271098389904927

# %%
data.plot(kind = 'scatter', x = 'petal.width', y = 'petal.length', figsize = (9,9), color = 'black')
y_pred = model.predict(X = pd.DataFrame(data['petal.width']))
plt.plot(data['petal.width'],y_pred,color='blue')

# %%
# hàm bậc 2
model = linear_model.LinearRegression()
X = pd.DataFrame([data['petal.width'], data['petal.width']**2]).T
model.fit(X, y=data['petal.length'])
print('Intercept cua mo hinh: ',model.intercept_)
print('Coeffient cua mo hinh: ',model.coef_)
z = model.score(X,y =data['petal.length'])
print('Do chinh xac cua mo hinh: ',z)
# Out:
# Intercept cua mo hinh:  0.6780834430199656
# Coeffient cua mo hinh:  [ 3.45483353 -0.52769182]
# Do chinh xac cua mo hinh:  0.9466917335841822

# %%
range = np.arange(0,3,0.1)
data.plot(kind = 'scatter', x = 'petal.width', y = 'petal.length', figsize = (9,9), color = 'black')
predictor = pd.DataFrame([range,range**2]).T
y_pred = model.predict(X = predictor)
plt.plot(range, y_pred,color = 'blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# hàm bậc 5
model = linear_model.LinearRegression()
X = pd.DataFrame([data['petal.width'], data['petal.width']**2,data['petal.width']**3,data['petal.width']**4,data['petal.width']**5]).T
model.fit(X, y=data['petal.length'])
print('Intercept cua mo hinh: ',model.intercept_)
print('Coeffient cua mo hinh: ',model.coef_)
z = model.score(X,y =data['petal.length'])
print('Do chinh xac cua mo hinh: ',z)
# Out:
# Intercept cua mo hinh:  1.8156072786499409
# Coeffient cua mo hinh:  [ -4.28855717  12.94834406 -10.04547592   3.49431411  -0.469525  ]
# Do chinh xac cua mo hinh:  0.9546640609523158

# %%
range = np.arange(0,3,0.1)
data.plot(kind = 'scatter', x = 'petal.width', y = 'petal.length', figsize = (9,9), color = 'black')
predictor = pd.DataFrame([range,range**2,range**3,range**4,range**5]).T
y_pred = model.predict(X = predictor)
plt.plot(range, y_pred,color = 'blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
